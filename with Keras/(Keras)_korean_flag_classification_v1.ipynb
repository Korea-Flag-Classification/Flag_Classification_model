# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from PIL import Image
from keras.optimizers import Adam
from keras.applications import InceptionV3
from keras.applications import ResNet50

import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np

# %%
img = image.load_img('/content/drive/MyDrive/datasets/flag/train/korean flag/000001 (2).jpg')

# %%
plt.imshow(img)

# %%
cv2.imread('/content/drive/MyDrive/datasets/flag/train/korean flag/000001 (2).jpg').shape
# Out:
# (833, 1200, 3)

# %%
train = ImageDataGenerator(rescale = 1/255)
val =ImageDataGenerator(rescale=1/255)

# %%
train_dataset = train.flow_from_directory('/content/drive/MyDrive/datasets/flag/train/',
                                          target_size = (200,200),
                                          batch_size = 32,
                                          shuffle=True,
                                          class_mode='binary')

val_dataset = train.flow_from_directory('/content/drive/MyDrive/datasets/flag/val/',
                                          target_size = (200,200),
                                          batch_size = 32,
                                          shuffle=True,
                                          class_mode='binary')
# Out:
# Found 1013 images belonging to 2 classes.
# Found 154 images belonging to 2 classes.

# %%
train_dataset.class_indices
# Out:
# {'korean flag': 0, 'no korean flag': 1}

# %% [markdown]
# ## model1 CNN

# %%
model = tf.keras.models.Sequential([
                                    tf.keras.layers.Conv2D(16,(3,3),activation='relu',input_shape=(200,200,3)),
                                    tf.keras.layers.MaxPool2D(2,2),

                                    tf.keras.layers.Conv2D(32,(3,3),activation='relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    
                                    tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
                                    tf.keras.layers.MaxPool2D(2,2),

                                    tf.keras.layers.Flatten(),

                                    tf.keras.layers.Dense(512, activation='relu'),

                                    tf.keras.layers.Dense(1, activation='sigmoid')
                                    
])

# %% [markdown]
# ## model2 resnet50

# %%
res50 = ResNet50(include_top=True, weights='imagenet')

for layer in res50.layers:
    layer.trainable=False

# %%
x = res50.output # param num= 2048
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)

prediction = tf.keras.layers.Dense(2, activation='sigmoid')(x)

model2 = tf.keras.Model(res50.input, prediction) # model = tf.keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# ## model 3  Inceptionv3

# %%
Inceptionv3 = InceptionV3(include_top=False,weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step

# %%
from keras import layers
import keras

# %%
x = Inceptionv3.output # param num= 2048
x = layers.GlobalAveragePooling2D()(x)
x = Inceptionv3.output # param num= 2048
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(512,activation='elu')(x)
x = layers.BatchNormalization()(x)

prediction = layers.Dense(1, activation='sigmoid')(x)

model3 =keras.Model(Inceptionv3.input, prediction) # model = tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
model3.compile(loss= tf.keras.losses.BinaryCrossentropy() , optimizer= keras.optimizers.Nadam(lr=0.001), metrics=['accuracy'])

# %%
model_fit = model3.fit(train_dataset,
                      steps_per_epoch = 20,
                      epochs= 50,
                      validation_data = val_dataset)
# Out:
# Epoch 1/50
# 10/20 [==============>...............] - ETA: 1:45 - loss: 1.8752 - accuracy: 0.6472
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 20/20 [==============================] - 294s 15s/step - loss: 1.1512 - accuracy: 0.7615 - val_loss: 1.9858 - val_accuracy: 0.6948
# Epoch 2/50
# 20/20 [==============================] - 90s 4s/step - loss: 0.3091 - accuracy: 0.8855 - val_loss: 26.1510 - val_accuracy: 0.6948
# Epoch 3/50
# 20/20 [==============================] - 36s 2s/step - loss: 0.2519 - accuracy: 0.8983 - val_loss: 60.7862 - val_accuracy: 0.6948
# Epoch 4/50
# 20/20 [==============================] - 21s 1s/step - loss: 0.1213 - accuracy: 0.9650 - val_loss: 5.4771 - val_accuracy: 0.6948
# Epoch 5/50
# 20/20 [==============================] - 15s 757ms/step - loss: 0.1208 - accuracy: 0.9650 - val_loss: 0.9750 - val_accuracy: 0.7597
# Epoch 6/50
# 20/20 [==============================] - 14s 722ms/step - loss: 0.0658 - accuracy: 0.9766 - val_loss: 0.5113 - val_accuracy: 0.8442
# Epoch 7/50
# 20/20 [==============================] - 13s 669ms/step - loss: 0.0193 - accuracy: 0.9969 - val_loss: 0.4381 - val_accuracy: 0.8701
# Epoch 8/50
# 20/20 [==============================] - 12s 612ms/step - loss: 0.0293 - accuracy: 0.9936 - val_loss: 0.6248 - val_accuracy: 0.8182
# Epoch 9/50
# 20/20 [==============================] - 12s 602ms/step - loss: 0.1094 - accuracy: 0.9746 - val_loss: 0.5842 - val_accuracy: 0.8377
# Epoch 10/50
# 20/20 [==============================] - 12s 621ms/step - loss: 0.1496 - accuracy: 0.9507 - val_loss: 0.4851 - val_accuracy: 0.8571
# Epoch 11/50
# 20/20 [==============================] - 12s 601ms/step - loss: 0.0468 - accuracy: 0.9857 - val_loss: 1.1271 - val_accuracy: 0.7987
# Epoch 12/50
# 20/20 [==============================] - 13s 626ms/step - loss: 0.0404 - accuracy: 0.9857 - val_loss: 0.6251 - val_accuracy: 0.8701
# Epoch 13/50
# 20/20 [==============================] - 14s 683ms/step - loss: 0.0091 - accuracy: 0.9984 - val_loss: 0.6592 - val_accuracy: 0.8636
# Epoch 14/50
# 20/20 [==============================] - 13s 637ms/step - loss: 0.0232 - accuracy: 0.9905 - val_loss: 0.4388 - val_accuracy: 0.9026
# Epoch 15/50
# 20/20 [==============================] - 13s 657ms/step - loss: 0.0148 - accuracy: 0.9936 - val_loss: 0.4210 - val_accuracy: 0.8701
# Epoch 16/50
# 20/20 [==============================] - 13s 630ms/step - loss: 0.0356 - accuracy: 0.9891 - val_loss: 0.3441 - val_accuracy: 0.8896
# Epoch 17/50
# 20/20 [==============================] - 12s 623ms/step - loss: 0.0853 - accuracy: 0.9781 - val_loss: 0.5820 - val_accuracy: 0.8636
# Epoch 18/50
# 20/20 [==============================] - 13s 668ms/step - loss: 0.0506 - accuracy: 0.9841 - val_loss: 1.0093 - val_accuracy: 0.7792
# Epoch 19/50
# 20/20 [==============================] - 13s 625ms/step - loss: 0.0364 - accuracy: 0.9889 - val_loss: 0.4190 - val_accuracy: 0.9026
# Epoch 20/50
# 20/20 [==============================] - 11s 572ms/step - loss: 0.0160 - accuracy: 0.9969 - val_loss: 0.5261 - val_accuracy: 0.8701
# Epoch 21/50
# 20/20 [==============================] - 12s 624ms/step - loss: 0.0183 - accuracy: 0.9937 - val_loss: 0.6938 - val_accuracy: 0.8442
# Epoch 22/50
# 20/20 [==============================] - 13s 634ms/step - loss: 0.0407 - accuracy: 0.9825 - val_loss: 1.1414 - val_accuracy: 0.7662
# Epoch 23/50
# 20/20 [==============================] - 13s 627ms/step - loss: 0.0539 - accuracy: 0.9873 - val_loss: 0.8167 - val_accuracy: 0.8312
# Epoch 24/50
# 20/20 [==============================] - 12s 613ms/step - loss: 0.0653 - accuracy: 0.9825 - val_loss: 4.8211 - val_accuracy: 0.6104
# Epoch 25/50
# 20/20 [==============================] - 13s 668ms/step - loss: 0.0505 - accuracy: 0.9859 - val_loss: 0.3578 - val_accuracy: 0.9091
# Epoch 26/50
# 20/20 [==============================] - 13s 669ms/step - loss: 0.0395 - accuracy: 0.9873 - val_loss: 0.3490 - val_accuracy: 0.9091
# Epoch 27/50
# 20/20 [==============================] - 12s 621ms/step - loss: 0.0318 - accuracy: 0.9873 - val_loss: 0.5483 - val_accuracy: 0.8571
# Epoch 28/50
# 20/20 [==============================] - 13s 660ms/step - loss: 0.0154 - accuracy: 0.9906 - val_loss: 0.3754 - val_accuracy: 0.9091
# Epoch 29/50
# 20/20 [==============================] - 14s 679ms/step - loss: 0.0098 - accuracy: 0.9984 - val_loss: 0.3520 - val_accuracy: 0.8961
# Epoch 30/50
# 20/20 [==============================] - 13s 631ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.3945 - val_accuracy: 0.9026
# Epoch 31/50
# 20/20 [==============================] - 13s 633ms/step - loss: 0.1061 - accuracy: 0.9714 - val_loss: 0.3949 - val_accuracy: 0.9156
# Epoch 32/50
# 20/20 [==============================] - 13s 658ms/step - loss: 0.0180 - accuracy: 0.9952 - val_loss: 0.4260 - val_accuracy: 0.9026
# Epoch 33/50
# 20/20 [==============================] - 13s 667ms/step - loss: 0.0099 - accuracy: 0.9953 - val_loss: 0.3109 - val_accuracy: 0.9221
# Epoch 34/50
# 20/20 [==============================] - 14s 678ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.2930 - val_accuracy: 0.9416
# Epoch 35/50
# 20/20 [==============================] - 13s 632ms/step - loss: 0.0277 - accuracy: 0.9922 - val_loss: 1.1393 - val_accuracy: 0.7338
# Epoch 36/50
# 20/20 [==============================] - 13s 627ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.7467 - val_accuracy: 0.8182
# Epoch 37/50
# 20/20 [==============================] - 14s 676ms/step - loss: 0.0061 - accuracy: 0.9984 - val_loss: 0.3790 - val_accuracy: 0.9221
# Epoch 38/50
# 20/20 [==============================] - 12s 600ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4056 - val_accuracy: 0.9221
# Epoch 39/50
# 20/20 [==============================] - 13s 652ms/step - loss: 7.3905e-04 - accuracy: 1.0000 - val_loss: 0.4264 - val_accuracy: 0.9091
# Epoch 40/50
# 20/20 [==============================] - 12s 618ms/step - loss: 0.0043 - accuracy: 0.9968 - val_loss: 0.5384 - val_accuracy: 0.9091
# Epoch 41/50
# 20/20 [==============================] - 13s 631ms/step - loss: 7.4371e-04 - accuracy: 1.0000 - val_loss: 0.4277 - val_accuracy: 0.9156
# Epoch 42/50
# 20/20 [==============================] - 12s 614ms/step - loss: 6.1491e-04 - accuracy: 1.0000 - val_loss: 0.4032 - val_accuracy: 0.9221
# Epoch 43/50
# 20/20 [==============================] - 13s 652ms/step - loss: 2.4835e-04 - accuracy: 1.0000 - val_loss: 0.3774 - val_accuracy: 0.9416
# Epoch 44/50
# 20/20 [==============================] - 12s 610ms/step - loss: 2.0944e-04 - accuracy: 1.0000 - val_loss: 0.3715 - val_accuracy: 0.9416
# Epoch 45/50
# 20/20 [==============================] - 13s 631ms/step - loss: 5.0288e-04 - accuracy: 1.0000 - val_loss: 0.3595 - val_accuracy: 0.9416
# Epoch 46/50
# 20/20 [==============================] - 14s 675ms/step - loss: 3.3159e-04 - accuracy: 1.0000 - val_loss: 0.3551 - val_accuracy: 0.9351
# Epoch 47/50
# 20/20 [==============================] - 13s 652ms/step - loss: 3.7740e-04 - accuracy: 1.0000 - val_loss: 0.3472 - val_accuracy: 0.9351
# Epoch 48/50
# 20/20 [==============================] - 12s 614ms/step - loss: 3.7298e-04 - accuracy: 1.0000 - val_loss: 0.3463 - val_accuracy: 0.9351
# Epoch 49/50
# 20/20 [==============================] - 12s 608ms/step - loss: 2.5519e-04 - accuracy: 1.0000 - val_loss: 0.3586 - val_accuracy: 0.9351
# Epoch 50/50
# 20/20 [==============================] - 12s 603ms/step - loss: 8.7318e-05 - accuracy: 1.0000 - val_loss: 0.3636 - val_accuracy: 0.9351

# %%
acc = model_fit.history['accuracy']
val_acc = model_fit.history['val_accuracy']

loss=model_fit.history['loss']
val_loss=model_fit.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
file_path = tf.keras.utils.get_file('test7','https://lh3.googleusercontent.com/proxy/5SGLhDg_PHF5Hl52tU68svjEXVr6EXNwTN0UvDWX9qXyTcX_N4HG9Q3TFc1mHB9Yf5EkpZlisFpq8viIKoUndB6MM6-wy9AV_idcToBIHL9gYMQP') # 2번째 항에 웹에서 이미지 주소 붙이기
image = Image.open(file_path).convert('RGB')
image = image.resize((200,200))
image = np.array(image) 

image = image.reshape((200,200,3))
plt.imshow(image)
x_test = [image]
x_test = np.array(x_test)
x_test = x_test / 255

pred = model3.predict(x_test)
print(pred)
if pred < 0.5:
    print('태극기입니다')

else:
    print('태극기가 아닙니다')
# Out:
# Downloading data from https://lh3.googleusercontent.com/proxy/5SGLhDg_PHF5Hl52tU68svjEXVr6EXNwTN0UvDWX9qXyTcX_N4HG9Q3TFc1mHB9Yf5EkpZlisFpq8viIKoUndB6MM6-wy9AV_idcToBIHL9gYMQP
# 32768/28451 [==================================] - 0s 0us/step
# [[6.5255967e-06]]
# 태극기입니다

# %%
file_path = tf.keras.utils.get_file('test8','https://t1.daumcdn.net/cfile/tistory/230A724B54AF769F13') # 2번째 항에 웹에서 이미지 주소 붙이기
image = Image.open(file_path).convert('RGB')
image = image.resize((200,200))
image = np.array(image) 

image = image.reshape((200,200,3))
plt.imshow(image)
x_test = [image]
x_test = np.array(x_test)
x_test = x_test / 255

pred = model3.predict(x_test)
print(pred)
if pred < 0.5:
    print('태극기입니다')

else:
    print('태극기가 아닙니다')
# Out:
# Downloading data from https://t1.daumcdn.net/cfile/tistory/230A724B54AF769F13
# 32768/29163 [=================================] - 0s 5us/step
# [[1.]]
# 태극기가 아닙니다
